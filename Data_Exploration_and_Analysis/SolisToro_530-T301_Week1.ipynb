# %%
#Display the text “Hello World! My name is ...."
print("Hello World! My name is Daniel")

#Add two numbers together
number1 = 12
number2 = 7
addition = number1 + number2
print(f'{number1} + {number2} = {addition}')

#Subtract a number from another number
subtraction = number1 - number2
print(f'{number1} - {number2} = {subtraction}')

#Multiply two numbers
multiplication = number1 * number2
print(f'{number1} * {number2} = {multiplication}')

#Divide between two numbers
division = number1 / number2 
print(f'{number1} / {number2} = {division}')

#Concatenate two strings together (any words)
string1 = "Hello"
string2 = "World"
concatenate = string1 + " " + string2
print("String1 =", string1)
print("String2 =", string2)
print("Concatenated string =", concatenate)

#Create a list of 4 items (can be strings, numbers, both)
my_list = [8, "banana", 5, "apple"]
print("Initial list:", my_list)

#Append an item to your list (again, can be a string, number)
my_list.append(10)
print("List after append:", my_list)

#Create a tuple with 4 items (can be strings, numbers, both)
my_tuple = (10, "orange", 16, "grape")
print("Tuple= ", my_tuple)
# Out:
# Hello World! My name is Daniel
# 12 + 7 = 19
# 12 - 7 = 5
# 12 * 7 = 84
# 12 / 7 = 1.7142857142857142
# String1 = Hello
# String2 = World
# Concatenated string = Hello World
# Initial list: [8, 'banana', 5, 'apple']
# List after append: [8, 'banana', 5, 'apple', 10]
# Tuple=  (10, 'orange', 16, 'grape')
